# %%
#1.Find the error in the following Python code:
import math
print(Math.sqrt(16))

# %%
## Math shouldbe in lower case in print statement
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
def my_function():
    x += 5
    print(x)

x = 10
my_function()

# %%
##The variable x =10 should be called inside the function as global 
x=10
def my_function():
    global x
    x += 5
    print(x)
my_function()
# Out:
# 15

# %%
#3.x = 5
if x = 10:
    print("x is 10")

# %%
#Inside the condition in if assigment operator is used instead of comparsion
#3.x = 5
if x ==10:
    print("x is 10")
else:
    print("x is not 10")
# Out:
# x is not 10

# %%
#4.
numbers = [5, 3, 8, 2]
print(numbers.sort())

# %%
#Numbers.sort() returns nothing it just changes the original list ands stores the list in same namw
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.
def square(n):
    n * n

print(square(4))

# %%
#the function is not returning anything is just performs the operation,so a return should be specified
def square(n):
    sqr = n * n
    return sqr
print(square(4))
# Out:
# 16

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1] = 5

# %%
#tuples cannot be modified once created
#to change it first convert it to a list
my_tuple = (1, 2, 3)
tuplist = list(my_tuple)
tuplist[1]=5
print(tuplist)
modifiedtuple=tuple(tuplist)
print(modifiedtuple)
# Out:
# [1, 5, 3]
# (1, 5, 3)

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name))

# %%
#Print statement is wrong %s(string) and %d(integer) placeholers
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name,age))
# Out:
# My name is Alice and I am 25 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")

# %%
#for two lists to be equal,the elements and length of the list must be same and order too it can be checked by ==operator
a = [1, 2, 3]
b = [1, 2, 3]
if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
for i in range(5, 1):
    print(i)

# %%
#The range gives an iterable which needs a(start,stop,step).here start is 5 but stop is less than 5 so it runs and doesnot print
#so it can be played with different values for stop and step
for i in range(5,10, 1):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
#10.
student = {"name": "John", "age": 20}
print(student[name])

# %%
#to get values in a dictionary we need to use get()
student = {"name": "John", "age": 20}
print(student.get("name"))
# Out:
# John
