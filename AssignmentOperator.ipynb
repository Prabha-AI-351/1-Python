# %%
x=10
y=5
z=x+y

# %%
z
# Out:
# 15

# %%
print(z)
print("z")
# Out:
# 15
# z

# %%
First name = "GOD"
# Out:
#   Cell In[10], line 1
#     First name = "GOD"
#           ^
# SyntaxError: invalid syntax

# %%
11hunters = "spartan"
# Out:
#   Cell In[11], line 1
#     11hunters = "spartan"
#      ^
# SyntaxError: invalid decimal literal

# %%
#Requiremment:Addition of two numbers
#The number1 = 10
#The number2 = 20
#The answer : sum of two numbers

# %%
num1=10
num2=20
add=num1+num2
print("The number1 : " , num1)
print("The number2 : " , num2)
print("The answer : " , add)
# Out:
# The number1 :  10
# The number2 :  20
# The answer :  30

# %%
yourfavoritenum=input("Speak")
# Out:
# Speak 1

# %%
x=int(input("num1"))
y=int(input("num2"))
# Out:
# num1 10
# num2 20

# %%
print("sum: " ,x+y)
# Out:
# sum:  30
