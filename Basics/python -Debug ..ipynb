# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)

# %%
#Indentation
#Colon at the end
#Corrected code below
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)

# %%
#"b=5" ----->5 is assigned as a string;integer and variable data type cannot be added
#The code will throw an error
#Corrected code below
a=10
b=5
print(a+b)
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b

# %%
#Indentation error and colon at the end
#corrected code
def add_numbers(a, b):
    return a + b
print(add_numbers(20,10))
# Out:
# 30

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])

# %%
#indentaion 
#index out of range

# %%
#5.Find the error in the following Python code:
print "Hello, World!"

# %%
#No paranthses in print statement
print( "Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0

# %%
#zero division not possible

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

# %%
#variable name is not defined
#Different data types are added in the print statemen
name = "Alice"
age = 25
print("Name: ",name,"Age: ",age)
# Out:
# Name:  Alice Age:  25

# %%
#8.Find the error
for i in range(1, 10,-1):
    print(i)

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

# %%
#condtion should be in the bracket
#== operator should be used
x = 10
if (x==5):
    print("x is 5")

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)

# %%
#Colon @ the end of the code
def greet(name):
    print("Hello, " + name)
greet("kumar")
# Out:
# Hello, kumar
