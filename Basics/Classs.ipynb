# %%
#if
if(5>3):
    print("true")
# Out:
# true

# %%
#if-else
age=int(input('enter the age'))
if(age<18):
    print('child')
else:
    print('adult')
# Out:
# enter the age 26
# adult

# %%
#if-elif
age=int(input('enter the age'))
if(age<18):
    print('child')
elif(age<35):
    print('adult')
elif(age<59):
    print('citizn')
else:
    print('senior citizen')
# Out:
# enter the age 501
# senior citizen

# %%
#For loop
list=[23,45,67,37,89]
for temp in list:
    print(temp)
# Out:
# 23
# 45
# 67
# 37
# 89

# %%
for age in list:
    if(age<18):
     print('child')
    elif(age<35):
     print('adult')
    elif(age<59):
     print('citizn')
    else:
     print('senior citizen')
# Out:
# adult
# citizn
# senior citizen
# citizn
# senior citizen

# %%
#Without retun definition
list=[23,45,67,37,89]
def Agecat():
    for age in list:
        if(age<18):
            print('child')
            cata = 'child'
        elif(age<35):
            print('adult')
            cata = 'adult'
        elif(age<59):
            print('citizen')
            cata = 'citizen'
        else:
            print('senior citizen')
            cata = 'senior citizen'
        return cata

# %%
hh=Agecat()
print(hh)
# Out:
# adult
# adult

# %%
def agecategory():
    age=int(input('enter the age'))
    if(age<18):
        print('child')
        cata = 'child'
    elif(age<35):
        print('adult')
        cata = 'adult'
    elif(age<59):
        print('citizn')
        cata = 'citizen'
    else:
        print('senior citizen')
        cata = 'senior citizen'
    return cata

# %%
agecategory()
# Out:
# enter the age 9684
# senior citizen
# 'senior citizen'

# %%
#Static method
class difftasks:
    @staticmethod
    def OddEven():
        num = int(input('Enter a number : '))
        if(num % 2 != 0):
            print(num, 'is an oddd number')
        else:
            print(num, ' is an even number')
    @staticmethod
    def Elegible():
        gen = input('Your Gender: ')
        age = int(input('Your age: '))
        if((gen =='Male' and age<21) or (gen =='Female' and age<18)):
            print('Not ELIGIBLE')
        else:
            print('ELIGIBLE')
    @staticmethod
    def trianglearea():
        s1 = int(input('Height : '))
        s2 = int(input('Breadth : '))
        print('Area formula: (Height*Breadth)/2')
        A = (s1*s2)/2
        return A
    @staticmethod
    def percentage():
        s1 = int(input('Subject1 : '))
        s2 = int(input('Subject2 : '))
        s3 = int(input('Subject3 : '))
        s4 = int(input('Subject4 : '))
        s5 = int(input('Subject5 : '))
        tm = s1+s2+s3+s4+s5
        pcent = (tm/500)*100
        print('Total: ' , tm)
        print('Percentage: ',pcent)

# %%
oddnum=difftasks()

# %%
oddnum.OddEven()
# Out:
# Enter a number :  4568
# 4568  is an even number

# %%
percentage=difftasks()

# %%
percentage.percentage()
# Out:
# Subject1 :  99
# Subject2 :  15
# Subject3 :  64
# Subject4 :  64
# Subject5 :  56
# Total:  298
# Percentage:  59.599999999999994

# %%
#self method
class difftasks:
  
    def OddEven(self):
        self.num = int(input('Enter a number : '))
        if(self.num % 2 != 0):
            print(self.num, 'is an oddd number')
        else:
            print(self.num, ' is an even number')
  
    def Elegible(self):
        self.gen = input('Your Gender: ')
        self.age = int(input('Your age: '))
        if((self.gen =='Male' and self.age<21) or (self.gen =='Female' and self.age<18)):
            print('Not ELIGIBLE')
        else:
            print('ELIGIBLE')

    def trianglearea(self):
        self.s1 = int(input('Height : '))
        self.s2 = int(input('Breadth : '))
        print('Area formula: (Height*Breadth)/2')
        A = (self.s1*self.s2)/2
        return A
  
    def percentage(self):
        self.s1 = int(input('Subject1 : '))
        ssef.s2 = int(input('Subject2 : '))
        self.s3 = int(input('Subject3 : '))
        self.s4 = int(input('Subject4 : '))
        self.s5 = int(input('Subject5 : '))
        self.tm = self.s1+self.s2+self.s3+self.s4+self.s5
        self.pcent = (tm/500)*100
        print('Total: ' , self.tm)
        print('Percentage: ',self.pcent)

# %%
oddnum=difftasks()

# %%
oddnum.OddEven()
# Out:
# Enter a number :  2
# 2  is an even number
